# %%
import urllib.request as url
import json
import pandas as pd
import matplotlib.pyplot as plt

# %%
response = url.urlopen("https://api.covid19india.org/states_daily.json")

# %%
json_data = json.load(response)

# %%
type(json_data)
# Out:
# dict

# %%
# JSON - Javascript Object Notation
# {key : value}

# %%
json_data.keys()
# Out:
# dict_keys(['states_daily'])

# %%
dataset = json_data['states_daily']

# %%
df = pd.DataFrame(dataset)

# %%
df.head()
# Out:
#   an ap ar as br ch ct       date dd dl  ... sk     status tg tn tr  tt un  \
# 0  0  1  0  0  0  0  0  14-Mar-20  0  7  ...  0  Confirmed  1  1  0  81  0
# 1  0  0  0  0  0  0  0  14-Mar-20  0  1  ...  0  Recovered  0  0  0   9  0
# 2  0  0  0  0  0  0  0  14-Mar-20  0  1  ...  0   Deceased  0  0  0   2  0
# 3  0  0  0  0  0  0  0  15-Mar-20  0  0  ...  0  Confirmed  2  0  0  27  0
# 4  0  0  0  0  0  0  0  15-Mar-20  0  1  ...  0  Recovered  1  0  0   4  0
#
#    up ut wb
# 0  12  0  0
# 1   4  0  0
# 2   0  0  0
# 3   1  0  0
# 4   0  0  0
#
# [5 rows x 41 columns]

# %%
df.tail()
# Out:
#      an   ap  ar   as   br ch   ct       date dd    dl  ...  sk     status  \
# 337  12  376   1  416  277  2  112  04-Jul-20  0  2632  ...   0  Recovered
# 338   0   12   0    0    4  0    0  04-Jul-20  0    81  ...   0   Deceased
# 339   6  998  10  735  403  7   46  05-Jul-20  0  2244  ...  22  Confirmed
# 340   6  414   2  690  277  0   52  05-Jul-20  0  3083  ...   9  Recovered
# 341   0   14   0    0    2  0    0  05-Jul-20  0    63  ...   0   Deceased
#
#        tg    tn  tr     tt    un    up  ut   wb
# 337  1342  2214   3  14746     0   557  21  595
# 338     5    65   0    611     0    24   0   19
# 339  1590  4150  22  23941  -370  1153  31  895
# 340  1166  2186   4  15829     0   607  22  545
# 341     7    60   0    421     0    12   0   21
#
# [5 rows x 41 columns]

# %%
df.shape
# Out:
# (342, 41)
